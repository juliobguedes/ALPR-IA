# %% [markdown]
# # Amostra de Placas
#
# Cria um conjunto de imagens apenas com as placas dos veículos

# %% [markdown]
# ## Imports

# %%
import cv2

import matplotlib as mpl
from matplotlib import pyplot as plt
# %matplotlib inline

import numpy as np
import pandas as pd

import os, json, itertools

# %%
from classes.Image import Image

# %%
filepath = u'../../dataset'
outputpath = u'../data/placas'

# %% [markdown]
# ## File Import

# %%
metadata = json.load(open('../data/metadata_db.json', 'r'))
metadata
# Out:
# {'training': {'track0034[09]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '347 490 341 257',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '448 670 74 27',
#    'char 1': '453 682 7 11',
#    'char 2': '461 681 8 12',
#    'char 3': '471 681 7 12',
#    'char 4': '482 681 7 11',
#    'char 5': '491 680 7 11',
#    'char 6': '500 679 7 12',
#    'char 7': '509 679 7 12'},
#   'track0034[14]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '319 488 360 269',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '425 677 77 29',
#    'char 1': '429 690 9 12',
#    'char 2': '439 689 8 13',
#    'char 3': '449 689 8 12',
#    'char 4': '461 689 7 11',
#    'char 5': '470 688 8 12',
#    'char 6': '479 687 8 13',
#    'char 7': '489 687 7 12'},
#   'track0034[21]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '266 496 389 283',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '379 698 83 30',
#    'char 1': '384 711 9 14',
#    'char 2': '395 711 8 13',
#    'char 3': '405 711 8 12',
#    'char 4': '418 710 8 12',
#    'char 5': '428 709 7 13',
#    'char 6': '438 709 8 12',
#    'char 7': '448 708 8 13'},
#   'track0034[27]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '250 500 412 305',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '366 715 88 32',
#    'char 1': '372 729 9 14',
#    'char 2': '383 728 9 14',
#    'char 3': '394 728 8 14',
#    'char 4': '407 728 8 13',
#    'char 5': '418 727 8 14',
#    'char 6': '427 726 9 14',
#    'char 7': '439 726 7 13'},
#   'track0034[20]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '293 498 384 283',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '404 697 81 30',
#    'char 1': '410 711 8 12',
#    'char 2': '420 710 8 13',
#    'char 3': '430 710 7 12',
#    'char 4': '442 709 8 12',
#    'char 5': '452 708 8 13',
#    'char 6': '461 707 9 13',
#    'char 7': '472 707 7 13'},
#   'track0034[23]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '270 502 397 288',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '384 707 85 30',
#    'char 1': '390 721 8 13',
#    'char 2': '400 720 8 13',
#    'char 3': '411 720 7 12',
#    'char 4': '423 719 8 13',
#    'char 5': '433 719 8 12',
#    'char 6': '443 718 8 12',
#    'char 7': '454 717 7 13'},
#   'track0034[28]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '259 504 413 303',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '376 717 87 32',
#    'char 1': '382 731 9 14',
#    'char 2': '392 730 10 14',
#    'char 3': '404 730 8 13',
#    'char 4': '417 729 9 14',
#    'char 5': '427 728 9 14',
#    'char 6': '438 728 8 13',
#    'char 7': '448 727 9 14'},
#   'track0034[19]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '288 491 379 282',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '398 691 81 29',
#    'char 1': '403 703 9 13',
#    'char 2': '413 703 8 13',
#    'char 3': '424 704 7 11',
#    'char 4': '436 702 8 13',
#    'char 5': '446 702 7 12',
#    'char 6': '455 701 8 13',
#    'char 7': '465 701 7 12'},
#   'track0034[17]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '310 491 371 273',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '418 685 79 28',
#    'char 1': '422 697 9 13',
#    'char 2': '432 696 9 14',
#    'char 3': '442 696 9 13',
#    'char 4': '454 696 8 12',
#    'char 5': '463 695 9 12',
#    'char 6': '473 694 8 13',
#    'char 7': '483 694 8 13'},
#   'track0034[07]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '342 492 336 254',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '441 672 74 26',
#    'char 1': '446 683 8 12',
#    'char 2': '455 683 7 11',
#    'char 3': '464 683 7 11',
#    'char 4': '475 682 8 11',
#    'char 5': '483 682 8 11',
#    'char 6': '492 681 8 12',
#    'char 7': '502 681 7 11'},
#   'track0034[24]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '251 496 402 296',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '367 706 85 30',
#    'char 1': '373 719 8 14',
#    'char 2': '383 719 9 13',
#    'char 3': '394 719 8 13',
#    'char 4': '407 718 8 13',
#    'char 5': '417 718 8 12',
#    'char 6': '427 717 8 13',
#    'char 7': '437 716 9 14'},
#   'track0034[29]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '234 493 422 308',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '353 710 90 32',
#    'char 1': '359 724 9 15',
#    'char 2': '370 723 10 15',
#    'char 3': '381 723 10 15',
#    'char 4': '395 722 9 14',
#    'char 5': '405 721 10 15',
#    'char 6': '416 721 9 15',
#    'char 7': '427 721 8 14'},
#   'track0034[05]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '344 496 331 239',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '443 673 72 25',
#    'char 1': '448 683 7 12',
#    'char 2': '457 683 7 12',
#    'char 3': '466 683 7 11',
#    'char 4': '476 683 8 11',
#    'char 5': '485 682 8 11',
#    'char 6': '494 682 7 11',
#    'char 7': '503 681 7 12'},
#   'track0034[18]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '291 489 375 276',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '400 685 80 29',
#    'char 1': '404 697 9 14',
#    'char 2': '414 697 9 13',
#    'char 3': '425 697 8 13',
#    'char 4': '437 696 8 13',
#    'char 5': '446 696 9 12',
#    'char 6': '456 695 8 13',
#    'char 7': '466 695 8 13'},
#   'track0034[04]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '370 494 324 245',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '465 667 72 25',
#    'char 1': '470 677 7 13',
#    'char 2': '479 677 7 12',
#    'char 3': '488 678 7 10',
#    'char 4': '499 677 7 10',
#    'char 5': '507 676 7 11',
#    'char 6': '515 675 7 12',
#    'char 7': '524 675 7 12'},
#   'track0034[11]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '331 482 348 263',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '434 668 76 27',
#    'char 1': '439 679 8 12',
#    'char 2': '448 679 8 12',
#    'char 3': '457 679 8 12',
#    'char 4': '469 678 7 12',
#    'char 5': '477 678 9 12',
#    'char 6': '487 678 7 11',
#    'char 7': '496 677 8 12'},
#   'track0034[12]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '328 489 352 263',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '431 674 77 27',
#    'char 1': '436 685 8 13',
#    'char 2': '445 685 8 12',
#    'char 3': '455 685 8 12',
#    'char 4': '467 685 7 11',
#    'char 5': '476 684 7 12',
#    'char 6': '484 683 8 12',
#    'char 7': '494 683 7 12'},
#   'track0034[08]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '336 487 339 256',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '437 667 74 26',
#    'char 1': '441 678 8 12',
#    'char 2': '450 677 8 13',
#    'char 3': '459 678 8 12',
#    'char 4': '470 677 8 12',
#    'char 5': '480 677 7 11',
#    'char 6': '488 676 8 12',
#    'char 7': '498 676 6 11'},
#   'track0034[22]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '275 498 392 289',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '389 704 83 30',
#    'char 1': '394 717 8 13',
#    'char 2': '405 717 8 13',
#    'char 3': '415 717 8 12',
#    'char 4': '427 715 9 14',
#    'char 5': '437 715 9 13',
#    'char 6': '447 714 9 13',
#    'char 7': '458 714 7 12'},
#   'track0034[03]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '366 501 321 244',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '463 673 71 25',
#    'char 1': '467 683 8 12',
#    'char 2': '475 683 9 12',
#    'char 3': '485 683 7 11',
#    'char 4': '495 682 8 12',
#    'char 5': '504 682 7 11',
#    'char 6': '513 681 6 12',
#    'char 7': '521 681 7 12'},
#   'track0034[13]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '307 482 358 267',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '412 672 77 26',
#    'char 1': '417 683 9 12',
#    'char 2': '427 683 8 11',
#    'char 3': '437 683 7 11',
#    'char 4': '447 681 9 13',
#    'char 5': '457 681 8 12',
#    'char 6': '466 681 8 12',
#    'char 7': '476 681 8 12'},
#   'track0034[26]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '250 500 410 298',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '367 711 87 31',
#    'char 1': '372 725 9 14',
#    'char 2': '383 724 9 14',
#    'char 3': '394 724 8 13',
#    'char 4': '406 723 10 14',
#    'char 5': '417 723 9 13',
#    'char 6': '427 722 9 14',
#    'char 7': '438 722 9 13'},
#   'track0034[01]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '391 502 314 239',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '484 670 70 26',
#    'char 1': '489 681 7 12',
#    'char 2': '497 681 7 11',
#    'char 3': '506 681 7 11',
#    'char 4': '516 680 7 11',
#    'char 5': '524 679 8 12',
#    'char 6': '532 679 8 11',
#    'char 7': '541 679 7 11'},
#   'track0034[30]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '242 498 423 309',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '362 716 90 33',
#    'char 1': '368 731 9 14',
#    'char 2': '379 730 10 15',
#    'char 3': '390 730 10 14',
#    'char 4': '404 729 9 14',
#    'char 5': '415 728 9 14',
#    'char 6': '425 728 9 13',
#    'char 7': '437 727 7 14'},
#   'track0034[06]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '362 495 330 247',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '459 669 73 26',
#    'char 1': '464 680 8 11',
#    'char 2': '473 680 7 11',
#    'char 3': '482 680 7 11',
#    'char 4': '493 679 7 11',
#    'char 5': '501 678 8 12',
#    'char 6': '510 678 7 11',
#    'char 7': '519 678 7 11'},
#   'track0034[02]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '360 495 321 243',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '456 666 71 25',
#    'char 1': '461 676 7 12',
#    'char 2': '469 676 8 11',
#    'char 3': '478 676 7 11',
#    'char 4': '489 676 7 11',
#    'char 5': '497 675 7 11',
#    'char 6': '505 674 8 11',
#    'char 7': '515 674 6 11'},
#   'track0034[16]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '293 483 370 275',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '401 679 79 28',
#    'char 1': '406 691 9 13',
#    'char 2': '416 691 8 13',
#    'char 3': '426 691 8 12',
#    'char 4': '438 690 8 12',
#    'char 5': '448 690 7 12',
#    'char 6': '457 689 8 13',
#    'char 7': '467 689 7 13'},
#   'track0034[10]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '322 485 348 259',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '425 668 75 25',
#    'char 1': '430 679 7 11',
#    'char 2': '439 678 7 12',
#    'char 3': '448 678 8 12',
#    'char 4': '460 678 7 11',
#    'char 5': '469 678 7 11',
#    'char 6': '478 677 7 11',
#    'char 7': '487 676 8 12'},
#   'track0034[15]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '305 487 366 269',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '412 676 79 27',
#    'char 1': '417 688 8 13',
#    'char 2': '427 688 8 12',
#    'char 3': '437 688 7 12',
#    'char 4': '448 687 8 12',
#    'char 5': '458 687 7 12',
#    'char 6': '467 687 7 11',
#    'char 7': '476 686 8 12'},
#   'track0034[25]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '270 506 402 295',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2012',
#    'plate': 'FGD-3938',
#    'position_plate': '384 714 86 32',
#    'char 1': '390 729 9 13',
#    'char 2': '401 728 9 13',
#    'char 3': '411 728 9 13',
#    'char 4': '424 727 9 13',
#    'char 5': '434 726 9 13',
#    'char 6': '445 726 8 13',
#    'char 7': '455 725 8 13'},
#   'track0016[19]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '641 385 253 214',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '716 526 64 25',
#    'char 1': '720 532 7 13',
#    'char 2': '727 533 8 12',
#    'char 3': '735 533 8 12',
#    'char 4': '746 534 8 12',
#    'char 5': '754 534 6 13',
#    'char 6': '760 534 8 13',
#    'char 7': '768 534 8 14'},
#   'track0016[26]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '629 358 258 216',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '706 504 64 24',
#    'char 1': '709 510 7 13',
#    'char 2': '716 511 8 12',
#    'char 3': '724 511 8 12',
#    'char 4': '735 512 8 12',
#    'char 5': '744 512 5 12',
#    'char 6': '750 512 8 13',
#    'char 7': '758 512 8 13'},
#   'track0016[03]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '649 370 246 204',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '724 510 61 21',
#    'char 1': '727 516 7 12',
#    'char 2': '734 516 8 12',
#    'char 3': '742 516 7 12',
#    'char 4': '752 516 8 11',
#    'char 5': '761 516 4 11',
#    'char 6': '767 516 7 11',
#    'char 7': '774 516 7 11'},
#   'track0016[04]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '655 366 246 205',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '731 505 61 21',
#    'char 1': '734 511 7 12',
#    'char 2': '741 511 8 12',
#    'char 3': '749 511 7 12',
#    'char 4': '759 511 8 12',
#    'char 5': '768 511 4 12',
#    'char 6': '773 511 8 12',
#    'char 7': '781 511 7 12'},
#   'track0016[25]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '636 365 258 214',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '713 509 65 25',
#    'char 1': '716 516 8 12',
#    'char 2': '724 516 7 12',
#    'char 3': '732 517 7 12',
#    'char 4': '743 517 8 12',
#    'char 5': '752 517 4 13',
#    'char 6': '758 518 8 12',
#    'char 7': '766 518 7 12'},
#   'track0016[07]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '651 362 248 207',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '727 499 62 22',
#    'char 1': '730 505 7 13',
#    'char 2': '737 505 8 13',
#    'char 3': '745 506 7 12',
#    'char 4': '755 506 8 12',
#    'char 5': '764 506 5 12',
#    'char 6': '770 506 7 12',
#    'char 7': '778 506 7 12'},
#   'track0016[13]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '646 373 249 209',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '721 512 63 24',
#    'char 1': '724 519 8 12',
#    'char 2': '732 519 7 12',
#    'char 3': '739 519 8 12',
#    'char 4': '750 520 8 12',
#    'char 5': '759 520 5 12',
#    'char 6': '765 520 7 13',
#    'char 7': '773 521 7 12'},
#   'track0016[08]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '652 361 248 209',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '726 497 62 23',
#    'char 1': '729 503 8 13',
#    'char 2': '737 504 7 12',
#    'char 3': '744 504 8 12',
#    'char 4': '755 504 8 12',
#    'char 5': '763 504 6 13',
#    'char 6': '769 505 8 12',
#    'char 7': '777 505 7 12'},
#   'track0016[17]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '642 383 251 212',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '718 524 63 24',
#    'char 1': '721 531 7 12',
#    'char 2': '728 531 8 12',
#    'char 3': '736 531 8 12',
#    'char 4': '747 532 8 12',
#    'char 5': '756 532 5 13',
#    'char 6': '761 533 8 12',
#    'char 7': '770 533 7 12'},
#   'track0016[18]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '639 386 253 210',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '715 527 63 24',
#    'char 1': '718 533 8 12',
#    'char 2': '726 533 7 12',
#    'char 3': '733 533 8 13',
#    'char 4': '744 534 8 12',
#    'char 5': '753 534 5 13',
#    'char 6': '759 535 8 12',
#    'char 7': '767 535 7 12'},
#   'track0016[30]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '631 348 261 219',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '709 494 65 26',
#    'char 1': '712 501 8 13',
#    'char 2': '720 501 8 13',
#    'char 3': '728 502 8 13',
#    'char 4': '739 502 8 13',
#    'char 5': '748 502 5 14',
#    'char 6': '754 503 8 13',
#    'char 7': '762 503 8 13'},
#   'track0016[28]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '632 351 260 214',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '709 496 65 24',
#    'char 1': '713 502 7 12',
#    'char 2': '720 502 8 13',
#    'char 3': '728 503 8 12',
#    'char 4': '739 503 8 13',
#    'char 5': '748 503 5 14',
#    'char 6': '754 504 8 13',
#    'char 7': '762 504 8 13'},
#   'track0016[20]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '641 382 253 213',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '717 525 64 24',
#    'char 1': '720 531 8 13',
#    'char 2': '728 531 8 13',
#    'char 3': '736 532 7 12',
#    'char 4': '746 532 9 13',
#    'char 5': '755 532 6 13',
#    'char 6': '761 533 8 13',
#    'char 7': '769 533 8 13'},
#   'track0016[23]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '640 375 256 214',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '716 518 64 25',
#    'char 1': '720 525 7 12',
#    'char 2': '727 525 8 13',
#    'char 3': '735 525 8 13',
#    'char 4': '746 526 8 13',
#    'char 5': '755 526 5 13',
#    'char 6': '761 527 7 12',
#    'char 7': '769 527 7 12'},
#   'track0016[14]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '651 373 251 211',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '727 513 63 24',
#    'char 1': '730 519 8 13',
#    'char 2': '738 519 8 13',
#    'char 3': '746 520 7 12',
#    'char 4': '756 520 8 13',
#    'char 5': '765 520 5 13',
#    'char 6': '771 521 8 13',
#    'char 7': '779 522 7 12'},
#   'track0016[21]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '646 381 254 214',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '721 524 63 25',
#    'char 1': '724 530 7 13',
#    'char 2': '731 530 8 13',
#    'char 3': '739 531 8 12',
#    'char 4': '750 531 8 13',
#    'char 5': '759 532 5 13',
#    'char 6': '764 532 9 13',
#    'char 7': '773 532 7 13'},
#   'track0016[01]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '655 373 244 205',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '730 516 62 22',
#    'char 1': '734 522 7 12',
#    'char 2': '741 522 8 12',
#    'char 3': '749 522 7 12',
#    'char 4': '759 522 8 12',
#    'char 5': '768 521 4 13',
#    'char 6': '773 521 8 12',
#    'char 7': '781 521 7 12'},
#   'track0016[15]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '648 380 249 210',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '723 520 62 24',
#    'char 1': '726 526 7 12',
#    'char 2': '733 527 8 12',
#    'char 3': '741 527 8 12',
#    'char 4': '752 528 8 12',
#    'char 5': '761 528 4 12',
#    'char 6': '766 528 8 13',
#    'char 7': '774 528 8 13'},
#   'track0016[05]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '651 365 246 206',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '725 503 62 22',
#    'char 1': '728 509 8 12',
#    'char 2': '736 509 7 12',
#    'char 3': '743 509 7 12',
#    'char 4': '753 510 8 12',
#    'char 5': '763 510 3 11',
#    'char 6': '768 510 7 12',
#    'char 7': '776 510 7 12'},
#   'track0016[06]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '645 361 249 208',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '721 499 62 22',
#    'char 1': '724 505 8 12',
#    'char 2': '732 505 7 12',
#    'char 3': '739 505 8 12',
#    'char 4': '750 505 7 12',
#    'char 5': '758 505 5 12',
#    'char 6': '764 505 8 12',
#    'char 7': '772 505 7 13'},
#   'track0016[29]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '627 348 261 217',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '705 495 65 24',
#    'char 1': '708 501 8 13',
#    'char 2': '716 501 8 13',
#    'char 3': '724 502 8 12',
#    'char 4': '735 502 8 13',
#    'char 5': '744 502 5 14',
#    'char 6': '750 503 8 12',
#    'char 7': '758 503 8 13'},
#   'track0016[11]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '648 368 248 209',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '723 505 63 23',
#    'char 1': '726 511 8 12',
#    'char 2': '734 511 7 12',
#    'char 3': '741 512 8 12',
#    'char 4': '752 512 8 12',
#    'char 5': '761 512 5 13',
#    'char 6': '767 513 7 12',
#    'char 7': '774 513 8 12'},
#   'track0016[09]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '646 363 248 207',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '720 500 63 23',
#    'char 1': '724 507 7 12',
#    'char 2': '731 507 8 12',
#    'char 3': '739 507 8 12',
#    'char 4': '750 507 8 13',
#    'char 5': '758 508 5 12',
#    'char 6': '764 508 8 12',
#    'char 7': '772 508 7 12'},
#   'track0016[16]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '646 382 251 209',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '721 523 64 24',
#    'char 1': '725 529 8 12',
#    'char 2': '733 529 7 13',
#    'char 3': '740 530 8 12',
#    'char 4': '751 530 8 13',
#    'char 5': '760 531 5 12',
#    'char 6': '765 531 8 13',
#    'char 7': '773 532 8 12'},
#   'track0016[12]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '643 368 249 211',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '719 504 63 24',
#    'char 1': '722 510 7 12',
#    'char 2': '729 510 8 13',
#    'char 3': '737 511 8 12',
#    'char 4': '748 511 8 13',
#    'char 5': '757 511 4 13',
#    'char 6': '762 512 8 13',
#    'char 7': '770 512 8 13'},
#   'track0016[02]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '653 372 245 203',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '728 511 61 22',
#    'char 1': '732 518 6 12',
#    'char 2': '738 518 8 12',
#    'char 3': '746 518 7 12',
#    'char 4': '756 518 8 12',
#    'char 5': '765 518 5 12',
#    'char 6': '770 518 8 12',
#    'char 7': '778 518 7 12'},
#   'track0016[22]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '639 378 255 214',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '714 522 64 25',
#    'char 1': '718 528 7 13',
#    'char 2': '725 528 8 13',
#    'char 3': '733 529 8 12',
#    'char 4': '744 529 8 13',
#    'char 5': '753 530 5 13',
#    'char 6': '758 530 8 13',
#    'char 7': '766 530 8 13'},
#   'track0016[10]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '652 363 248 207',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '727 499 63 24',
#    'char 1': '731 506 7 12',
#    'char 2': '738 506 8 12',
#    'char 3': '746 506 7 12',
#    'char 4': '756 506 8 13',
#    'char 5': '765 506 5 14',
#    'char 6': '771 507 7 12',
#    'char 7': '779 507 7 12'},
#   'track0016[27]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '635 354 260 216',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '712 499 65 25',
#    'char 1': '716 506 7 12',
#    'char 2': '723 506 8 13',
#    'char 3': '731 507 8 12',
#    'char 4': '742 507 8 13',
#    'char 5': '751 507 5 13',
#    'char 6': '757 508 8 12',
#    'char 7': '765 508 8 12'},
#   'track0016[24]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '634 370 256 214',
#    'type': 'car',
#    'make': 'Fiat',
#    'model': 'Siena',
#    'year': '2015',
#    'plate': 'AZU-5133',
#    'position_plate': '710 514 64 24',
#    'char 1': '713 521 7 12',
#    'char 2': '720 521 8 12',
#    'char 3': '728 521 8 12',
#    'char 4': '739 522 8 12',
#    'char 5': '748 522 5 12',
#    'char 6': '754 522 8 13',
#    'char 7': '762 523 8 12'},
#   'track0028[01]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '538 253 549 624',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '541 563 124 45',
#    'char 1': '545 579 15 23',
#    'char 2': '561 579 15 23',
#    'char 3': '578 579 14 23',
#    'char 4': '598 579 15 23',
#    'char 5': '615 579 14 23',
#    'char 6': '630 580 15 22',
#    'char 7': '645 580 15 23'},
#   'track0028[05]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '555 270 538 609',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '557 573 121 45',
#    'char 1': '562 588 14 22',
#    'char 2': '577 589 15 22',
#    'char 3': '593 589 15 22',
#    'char 4': '614 589 14 22',
#    'char 5': '630 589 14 22',
#    'char 6': '645 590 13 22',
#    'char 7': '660 590 14 22'},
#   'track0028[24]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '575 231 531 615',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '577 524 119 45',
#    'char 1': '582 540 13 21',
#    'char 2': '597 540 14 22',
#    'char 3': '612 540 15 23',
#    'char 4': '632 541 14 21',
#    'char 5': '648 541 14 21',
#    'char 6': '664 541 13 21',
#    'char 7': '678 541 14 22'},
#   'track0028[10]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '565 278 531 594',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '567 578 121 44',
#    'char 1': '572 592 14 23',
#    'char 2': '586 593 16 22',
#    'char 3': '603 593 14 23',
#    'char 4': '623 594 14 22',
#    'char 5': '639 594 13 21',
#    'char 6': '654 594 14 22',
#    'char 7': '668 595 14 22'},
#   'track0028[20]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '599 258 525 602',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '599 550 118 43',
#    'char 1': '604 565 14 22',
#    'char 2': '618 565 15 22',
#    'char 3': '634 565 14 22',
#    'char 4': '654 566 14 21',
#    'char 5': '669 566 14 21',
#    'char 6': '684 566 14 21',
#    'char 7': '698 566 14 21'},
#   'track0028[26]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '600 236 527 620',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '601 529 119 43',
#    'char 1': '605 544 14 21',
#    'char 2': '619 544 15 22',
#    'char 3': '635 544 15 22',
#    'char 4': '655 545 14 21',
#    'char 5': '671 545 13 21',
#    'char 6': '686 545 13 21',
#    'char 7': '700 545 14 21'},
#   'track0028[18]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '586 264 530 590',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '586 558 121 44',
#    'char 1': '592 573 14 22',
#    'char 2': '607 574 15 22',
#    'char 3': '623 574 14 22',
#    'char 4': '642 574 15 22',
#    'char 5': '658 574 14 22',
#    'char 6': '672 575 15 21',
#    'char 7': '688 575 13 21'},
#   'track0028[06]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '569 276 535 603',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '570 578 121 45',
#    'char 1': '575 594 14 22',
#    'char 2': '590 594 15 22',
#    'char 3': '607 594 13 22',
#    'char 4': '626 595 14 21',
#    'char 5': '642 595 14 21',
#    'char 6': '658 595 13 22',
#    'char 7': '673 596 13 21'},
#   'track0028[15]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '583 272 528 597',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '584 568 120 45',
#    'char 1': '589 584 14 21',
#    'char 2': '604 584 14 21',
#    'char 3': '619 584 15 22',
#    'char 4': '640 585 14 21',
#    'char 5': '655 585 13 21',
#    'char 6': '670 585 14 21',
#    'char 7': '685 585 14 21'},
#   'track0028[14]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '586 276 526 593',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '585 572 119 44',
#    'char 1': '591 587 13 22',
#    'char 2': '605 587 15 22',
#    'char 3': '621 587 14 22',
#    'char 4': '641 588 14 21',
#    'char 5': '656 588 13 21',
#    'char 6': '672 588 13 21',
#    'char 7': '686 589 13 20'},
#   'track0028[13]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '571 277 530 598',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '572 575 120 44',
#    'char 1': '577 590 14 22',
#    'char 2': '591 591 16 21',
#    'char 3': '608 590 14 23',
#    'char 4': '628 591 14 21',
#    'char 5': '644 592 12 20',
#    'char 6': '659 592 13 21',
#    'char 7': '673 592 14 21'},
#   'track0028[02]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '538 259 543 606',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '539 567 123 45',
#    'char 1': '543 583 15 23',
#    'char 2': '559 583 15 23',
#    'char 3': '575 583 15 23',
#    'char 4': '596 583 15 23',
#    'char 5': '612 584 14 22',
#    'char 6': '628 584 14 23',
#    'char 7': '643 584 15 23'},
#   'track0028[16]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '582 269 527 591',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '581 567 120 43',
#    'char 1': '587 582 13 21',
#    'char 2': '601 582 14 22',
#    'char 3': '617 582 14 22',
#    'char 4': '637 583 14 20',
#    'char 5': '652 583 13 21',
#    'char 6': '667 583 14 22',
#    'char 7': '682 583 14 22'},
#   'track0028[21]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '580 249 529 607',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '582 541 120 43',
#    'char 1': '587 556 14 22',
#    'char 2': '602 556 14 22',
#    'char 3': '618 556 13 23',
#    'char 4': '637 557 15 21',
#    'char 5': '653 557 13 21',
#    'char 6': '668 557 14 21',
#    'char 7': '682 557 14 21'},
#   'track0028[28]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '600 242 531 619',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '602 539 119 44',
#    'char 1': '608 554 13 21',
#    'char 2': '622 555 14 20',
#    'char 3': '637 554 15 22',
#    'char 4': '658 555 14 21',
#    'char 5': '673 555 14 21',
#    'char 6': '688 555 14 21',
#    'char 7': '703 555 14 22'},
#   'track0028[09]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '573 282 530 599',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '574 581 120 45',
#    'char 1': '579 596 14 22',
#    'char 2': '594 597 15 22',
#    'char 3': '610 597 14 23',
#    'char 4': '629 597 15 23',
#    'char 5': '646 598 13 21',
#    'char 6': '661 598 14 22',
#    'char 7': '675 598 14 22'},
#   'track0028[04]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '554 268 539 604',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '556 572 123 46',
#    'char 1': '562 588 13 22',
#    'char 2': '576 589 15 22',
#    'char 3': '593 588 14 23',
#    'char 4': '613 589 14 22',
#    'char 5': '629 590 14 21',
#    'char 6': '644 590 15 21',
#    'char 7': '659 590 14 22'},
#   'track0028[19]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '585 259 530 609',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '587 554 119 43',
#    'char 1': '591 568 15 23',
#    'char 2': '606 568 16 23',
#    'char 3': '622 568 14 23',
#    'char 4': '642 569 14 22',
#    'char 5': '658 569 13 22',
#    'char 6': '673 570 13 21',
#    'char 7': '688 570 13 21'},
#   'track0028[29]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '600 244 531 618',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '603 538 119 44',
#    'char 1': '608 553 14 21',
#    'char 2': '622 553 15 21',
#    'char 3': '638 553 14 22',
#    'char 4': '658 554 14 21',
#    'char 5': '674 554 13 21',
#    'char 6': '688 554 14 21',
#    'char 7': '703 554 14 22'},
#   'track0028[08]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '565 279 532 600',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '567 580 120 44',
#    'char 1': '571 595 14 21',
#    'char 2': '586 595 15 22',
#    'char 3': '603 595 13 23',
#    'char 4': '622 596 14 22',
#    'char 5': '639 597 13 21',
#    'char 6': '654 597 13 22',
#    'char 7': '668 597 14 22'},
#   'track0028[12]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '580 278 528 597',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '580 576 121 44',
#    'char 1': '585 591 14 21',
#    'char 2': '600 591 15 21',
#    'char 3': '616 591 14 22',
#    'char 4': '636 591 14 22',
#    'char 5': '652 592 13 21',
#    'char 6': '667 592 14 21',
#    'char 7': '682 592 13 21'},
#   'track0028[30]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '580 245 533 624',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '580 544 121 44',
#    'char 1': '585 558 15 22',
#    'char 2': '600 559 16 22',
#    'char 3': '616 558 15 23',
#    'char 4': '636 560 15 22',
#    'char 5': '652 560 14 22',
#    'char 6': '667 560 15 22',
#    'char 7': '682 561 15 21'},
#   'track0028[27]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '578 233 534 622',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '581 529 121 45',
#    'char 1': '587 544 13 22',
#    'char 2': '601 545 14 21',
#    'char 3': '617 545 14 22',
#    'char 4': '637 545 14 22',
#    'char 5': '653 546 13 21',
#    'char 6': '668 546 14 21',
#    'char 7': '683 546 14 22'},
#   'track0028[22]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '584 244 528 615',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '584 536 120 44',
#    'char 1': '590 552 13 21',
#    'char 2': '604 552 14 21',
#    'char 3': '620 552 14 22',
#    'char 4': '639 553 14 21',
#    'char 5': '655 553 14 21',
#    'char 6': '670 553 14 21',
#    'char 7': '685 553 14 21'},
#   'track0028[23]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '594 241 528 618',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '595 535 119 43',
#    'char 1': '601 551 12 21',
#    'char 2': '615 550 14 22',
#    'char 3': '631 550 13 23',
#    'char 4': '650 551 14 21',
#    'char 5': '665 551 14 21',
#    'char 6': '681 551 13 21',
#    'char 7': '695 551 13 21'},
#   'track0028[03]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '553 260 540 604',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '554 567 124 46',
#    'char 1': '559 583 15 23',
#    'char 2': '575 584 15 22',
#    'char 3': '591 583 15 23',
#    'char 4': '612 584 14 22',
#    'char 5': '628 585 14 21',
#    'char 6': '643 585 14 21',
#    'char 7': '657 585 15 22'},
#   'track0028[11]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '574 281 528 597',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '575 580 120 44',
#    'char 1': '579 594 15 23',
#    'char 2': '595 595 14 22',
#    'char 3': '610 595 15 23',
#    'char 4': '630 596 15 22',
#    'char 5': '646 596 14 22',
#    'char 6': '662 596 13 22',
#    'char 7': '676 597 14 21'},
#   'track0028[25]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '585 231 532 622',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '588 528 119 43',
#    'char 1': '594 543 13 21',
#    'char 2': '608 543 14 22',
#    'char 3': '623 543 15 23',
#    'char 4': '643 544 14 21',
#    'char 5': '660 544 12 21',
#    'char 6': '674 544 14 22',
#    'char 7': '689 544 14 22'},
#   'track0028[17]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '596 269 524 598',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '597 565 119 43',
#    'char 1': '602 580 14 21',
#    'char 2': '617 580 15 21',
#    'char 3': '633 580 13 22',
#    'char 4': '652 580 14 21',
#    'char 5': '667 580 14 22',
#    'char 6': '682 580 15 22',
#    'char 7': '697 580 14 22'},
#   'track0028[07]': {'camera': 'Huawei P9 Lite',
#    'position_vehicle': '561 279 534 602',
#    'type': 'car',
#    'make': 'Land Rover',
#    'model': 'Defender 110',
#    'year': '2000',
#    'plate': 'BSV-9863',
#    'position_plate': '563 578 121 45',
#    'char 1': '568 594 14 22',
#    'char 2': '583 594 15 22',
#    'char 3': '600 594 13 23',
#    'char 4': '619 595 14 21',
#    'char 5': '635 595 14 23',
#    'char 6': '650 595 15 23',
#    'char 7': '665 596 14 22'},
#   'track0052[02]': {'camera': 'iPhone 7 Plus',
#    'position_vehicle': '696 437 394 369',
#    'type': 'car',
#    'make': 'GM Chevrolet',
#    'model': 'Spin',
#    'year': '2014',
#    'plate': 'AZH-5961',
#    'position_plate': '843 708 100 37',
#    'char 1': '849 720 11 17',
#    'char 2': '861 720 12 17',
#    'char 3': '873 720 11 18',
#    'char 4': '890 722 11 16',
#    'char 5': '902 722 11 17',
#    'char 6': '914 723 11 16',
#    'char 7': '928 722 6 17'},
#   'track0052[28]': {'camera': 'iPhone 7 Plus',
#    'position_vehicle': '710 470 303 278',
#    'type': 'car',
#    'make': 'GM Chevrolet',
#    'model': 'Spin',
#    'year': '2014',
#    'plate': 'AZH-5961',
#    'position_plate': '839 667 73 27',
#    'char 1': '843 676 8 13',
#    'char 2': '852 675 8 14',
#    'char 3': '860 675 9 14',
#    'char 4': '873 676 8 14',
#    'char 5': '882 677 8 13',
#    'char 6': '890 677 9 13',
#    'char 7': '900 677 5 13'},
#   'track0052[08]': {'camera': 'iPhone 7 Plus',
#    'position_vehicle': '712 445 361 340',
#    'type': 'car',
#    'make': 'GM Chevrolet',
#    'model': 'Spin',
#    'year': '2014',
#    'plate': 'AZH-5961',
#    'position_plate': '849 689 91 34',
#    'char 1': '855 701 10 15',
#    'char 2': '866 701 10 15',
#    'char 3': '876 701 11 16',
#    'char 4': '892 702 10 16',
#    'char 5': '903 702 10 16',
#    'char 6': '914 703 10 14',
#    'char 7': '926 703 6 15'},
#   'track0052[27]': {'camera': 'iPhone 7 Plus',
#    'position_vehicle': '713 468 303 282',
#    'type': 'car',
#    'make': 'GM Chevrolet',
#    'model': 'Spin',
#    'year': '2014',
#    'plate': 'AZH-5961',
#    'position_plate': '839 669 75 28',
#    'char 1': '844 678 9 13',
#    'char 2': '853 678 10 14',
#    'char 3': '862 678 9 14',
#    'char 4': '875 678 9 14',
#    'char 5': '884 679 8 13',
#    'char 6': '892 679 9 14',
#    'char 7': '902 679 5 14'},
#   'track0052[01]': {'camera': 'iPhone 7 Plus',
#    'position_vehicle': '694 435 401 374',
#    'type': 'car',
#    'make': 'GM Chevrolet',
#    'model': 'Spin',
#    'year': '2014',
#    'plate': 'AZH-5961',
#    'position_plate': '843 712 102 36',
#    'char 1': '849 724 11 17',
#    'char 2': '860 724 13 17',
#    'char 3': '873 724 11 18',
#    'char 4': '891 725 11 17',
#    'char 5': '903 725 11 18',
#    'char 6': '915 726 11 17',
#    'char 7': '930 726 5 17'},
#   'track0052[20]': {'camera': 'iPhone 7 Plus',
#    'position_vehicle': '720 463 316 297',
#    'type': 'car',
#    'make': 'GM Chevrolet',
#    'model': 'Spin',
#    'year': '2014',
#    'plate': 'AZH-5961',
#    'position_plate': '847 675 79 28',
#    'char 1': '852 684 8 14',
#    'char 2': '861 684 9 14',
#    'char 3': '870 684 10 15',
#    'char 4': '884 685 9 14',
#    'char 5': '893 685 9 14',
#    'char 6': '902 685 10 15',
#    'char 7': '913 685 5 15'},
#   'track0052[11]': {'camera': 'iPhone 7 Plus',
#    'position_vehicle': '716 449 347 327',
#    'type': 'car',
#    'make': 'GM Chevrolet',
#    'model': 'Spin',
#    'year': '2014',
#    'plate': 'AZH-5961',
#    'position_plate': '851 684 87 32',
#    'char 1': '856 694 10 16',
#    'char 2': '867 695 10 16',
#    'char 3': '877 695 10 15',
#    'char 4': '891 695 11 15',
#    'char 5': '902 696 10 15',
#    'char 6': '912 696 11 16',
#    'char 7': '925 696 5 17'},
#   'track0052[22]': {'camera': 'iPhone 7 Plus',
#    'position_vehicle': '721 465 309 289',
#    'type': 'car',
#    'make': 'GM Chevrolet',
#    'model': 'Spin',
#    'year': '2014',
#    'plate': 'AZH-5961',
#    'position_plate': '845 672 76 28',
#    'char 1': '849 681 9 14',
#    'char 2': '858 681 9 14',
#    'char 3': '867 681 10 14',
#    'char 4': '881 682 9 13',
#    'char 5': '890 682 8 14',
#    'char 6': '899 682 9 14',
#    'char 7': '910 682 5 15'},
#   'track0052[24]': {'camera': 'iPhone 7 Plus',
#    'position_vehicle': '721 467 302 285',
#    'type': 'car',
#    'make': 'GM Chevrolet',
#    'model': 'Spin',
#    'year': '2014',
#    'plate': 'AZH-5961',
#    'position_plate': '844 670 75 27',
#    'char 1': '848 679 8 13',
#    'char 2': '857 678 9 14',
#    'char 3': '866 679 9 14',
#    'char 4': '879 679 9 14',
#    'char 5': '888 680 8 13',
#    'char 6': '896 680 9 14',
#    'char 7': '907 680 5 14'},
#   'track0052[03]': {'camera': 'iPhone 7 Plus',
#    'position_vehicle': '699 438 388 363',
#    'type': 'car',
#    'make': 'GM Chevrolet',
#    'model': 'Spin',
#    'year': '2014',
#    'plate': 'AZH-5961',
#    'position_plate': '844 705 98 35',
#    'char 1': '850 716 10 17',
#    'char 2': '861 716 12 17',
#    'char 3': '873 717 11 17',
#    'char 4': '890 718 11 16',
#    'char 5': '902 718 11 16',
#    'char 6': '913 718 12 17',
#    'char 7': '928 719 5 16'},
#   'track0052[06]': {'camera': 'iPhone 7 Plus',
#    'position_vehicle': '709 443 369 348',
#    'type': 'car',
#    'make': 'GM Chevrolet',
#    'model': 'Spin',
#    'year': '2014',
#    'plate': 'AZH-5961',
#    'position_plate': '848 696 93 34',
#    'char 1': '852 707 11 16',
#    'char 2': '864 707 11 16',
#    'char 3': '875 707 11 17',
#    'char 4': '891 709 11 15',
#    'char 5': '902 709 11 16',
#    'char 6': '913 709 11 16',
#    'char 7': '927 709 5 16'},
#   'track0052[12]': {'camera': 'iPhone 7 Plus',
#    'position_vehicle': '719 452 343 323',
#    'type': 'car',
#    'make': 'GM Chevrolet',
#    'model': 'Spin',
#    'year': '2014',
#    'plate': 'AZH-5961',
#    'position_plate': '851 683 86 32',
#    'char 1': '856 694 9 14',
#    'char 2': '866 693 10 16',
#    'char 3': '876 694 10 15',
#    'char 4': '891 694 10 16',
#    'char 5': '902 695 9 15',
#    'char 6': '912 695 9 16',
#    'char 7': '924 696 5 15'},
#   'track0052[21]': {'camera': 'iPhone 7 Plus',
#    'position_vehicle': '719 463 314 294',
#    'type': 'car',
#    'make': 'GM Chevrolet',
#    'model': 'Spin',
#    'year': '2014',
#    'plate': 'AZH-5961',
#    'position_plate': '846 674 77 28',
#    'char 1': '850 683 9 13',
#    'char 2': '859 683 10 14',
#    'char 3': '869 683 9 14',
#    'char 4': '882 683 9 14',
#    'char 5': '891 684 9 13',
#    'char 6': '900 684 9 14',
#    'char 7': '911 684 5 14'},
#   'track0052[05]': {'camera': 'iPhone 7 Plus',
#    'position_vehicle': '706 441 375 351',
#    'type': 'car',
#    'make': 'GM Chevrolet',
#    'model': 'Spin',
#    'year': '2014',
#    'plate': 'AZH-5961',
#    'position_plate': '846 699 96 34',
#    'char 1': '852 710 11 16',
#    'char 2': '864 710 10 16',
#    'char 3': '874 710 12 17',
#    'char 4': '892 711 10 16',
#    'char 5': '903 711 10 16',
#    'char 6': '913 712 11 16',
#    'char 7': '927 712 6 17'},
#   'track0052[17]': {'camera': 'iPhone 7 Plus',
#    'position_vehicle': '721 459 326 306',
#    'type': 'car',
#    'make': 'GM Chevrolet',
#    'model': 'Spin',
#    'year': '2014',
#    'plate': 'AZH-5961',
#    'position_plate': '850 679 82 29',
#    'char 1': '855 688 9 14',
#    'char 2': '865 688 9 14',
#    'char 3': '874 688 10 15',
#    'char 4': '888 689 10 14',
#    'char 5': '898 689 10 14',
#    'char 6': '908 689 9 15',
#    'char 7': '919 690 6 15'},
#   'track0052[26]': {'camera': 'iPhone 7 Plus',
#    'position_vehicle': '718 469 301 281',
#    'type': 'car',
#    'make': 'GM Chevrolet',
#    'model': 'Spin',
#    'year': '2014',
#    'plate': 'AZH-5961',
#    'position_plate': '841 669 74 27',
#    'char 1': '846 678 8 13',
#    'char 2': '854 677 9 14',
#    'char 3': '863 678 10 13',
#    'char 4': '876 678 9 14',
#    'char 5': '885 678 9 15',
#    'char 6': '893 679 9 13',
#    'char 7': '904 679 5 14'},
#   'track0052[30]': {'camera': 'iPhone 7 Plus',
#    'position_vehicle': '703 470 303 274',
#    'type': 'car',
#    'make': 'GM Chevrolet',
#    'model': 'Spin',
#    'year': '2014',
#    'plate': 'AZH-5961',
#    'position_plate': '836 666 72 25',
#    'char 1': '840 673 9 13',
#    'char 2': '849 673 8 13',
#    'char 3': '857 673 9 13',
#    'char 4': '869 674 9 13',
#    'char 5': '878 675 9 12',
#    'char 6': '886 675 9 12',
#    'char 7': '897 674 4 14'},
#   'track0052[19]': {'camera': 'iPhone 7 Plus',
#    'position_vehicle': '721 463 318 297',
#    'type': 'car',
#    'make': 'GM Chevrolet',
#    'model': 'Spin',
#    'year': '2014',
#    'plate': 'AZH-5961',
#    'position_plate': '848 675 79 29',
#    'char 1': '853 685 9 13',
#    'char 2': '861 684 10 15',
#    'char 3': '871 684 10 15',
#    'char 4': '885 685 9 14',
#    'char 5': '894 685 10 15',
#    'char 6': '904 686 9 14',
#    'char 7': '915 685 5 16'},
#   'track0052[29]': {'camera': 'iPhone 7 Plus',
#    'position_vehicle': '706 471 302 275',
#    'type': 'car',
#    'make': 'GM Chevrolet',
#    'model': 'Spin',
#    'year': '2014',
#    'plate': 'AZH-5961',
#    'position_plate': '837 667 72 26',
#    'char 1': '841 675 8 13',
#    'char 2': '849 675 9 13',
#    'char 3': '858 675 10 13',
#    'char 4': '871 676 9 13',
#    'char 5': '880 676 8 13',
#    'char 6': '888 676 9 13',
# ...
#    'char 4': '878 473 8 11',
#    'char 5': '887 473 4 12',
#    'char 6': '893 473 7 12',
#    'char 7': '900 473 8 12'},
#   'track0104[22]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '758 374 239 211',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '849 469 65 23',
#    'char 1': '852 476 7 13',
#    'char 2': '860 476 7 13',
#    'char 3': '867 477 8 12',
#    'char 4': '879 477 8 12',
#    'char 5': '888 477 5 12',
#    'char 6': '894 478 8 11',
#    'char 7': '902 478 8 12'},
#   'track0104[01]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '765 375 210 186',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '845 459 56 19',
#    'char 1': '848 465 6 11',
#    'char 2': '854 465 7 11',
#    'char 3': '861 466 7 11',
#    'char 4': '871 466 7 10',
#    'char 5': '879 466 4 11',
#    'char 6': '884 466 8 11',
#    'char 7': '892 466 6 11'},
#   'track0104[14]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '759 373 224 201',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '844 462 61 22',
#    'char 1': '847 469 7 12',
#    'char 2': '854 469 7 12',
#    'char 3': '861 469 7 12',
#    'char 4': '872 470 8 11',
#    'char 5': '881 470 4 11',
#    'char 6': '886 470 8 12',
#    'char 7': '894 470 7 12'},
#   'track0104[04]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '761 377 212 189',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '843 463 57 19',
#    'char 1': '846 469 6 11',
#    'char 2': '852 469 7 11',
#    'char 3': '859 469 8 11',
#    'char 4': '869 469 8 11',
#    'char 5': '878 470 3 10',
#    'char 6': '883 470 7 10',
#    'char 7': '889 470 7 10'},
#   'track0104[23]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '758 376 242 211',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '851 471 65 23',
#    'char 1': '854 479 8 12',
#    'char 2': '862 478 8 14',
#    'char 3': '870 478 8 14',
#    'char 4': '881 479 9 12',
#    'char 5': '891 479 4 13',
#    'char 6': '896 480 8 12',
#    'char 7': '905 480 7 12'},
#   'track0104[21]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '760 373 236 208',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '850 467 64 23',
#    'char 1': '853 474 8 12',
#    'char 2': '861 474 7 12',
#    'char 3': '868 475 8 12',
#    'char 4': '880 475 8 12',
#    'char 5': '889 475 4 13',
#    'char 6': '894 476 8 12',
#    'char 7': '902 476 8 12'},
#   'track0104[13]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '760 373 223 200',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '843 462 61 22',
#    'char 1': '846 469 8 11',
#    'char 2': '854 469 7 11',
#    'char 3': '861 470 8 11',
#    'char 4': '872 470 7 11',
#    'char 5': '880 471 4 10',
#    'char 6': '886 470 7 11',
#    'char 7': '893 470 7 11'},
#   'track0104[18]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '760 372 232 206',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '849 462 62 23',
#    'char 1': '852 470 7 12',
#    'char 2': '859 470 8 12',
#    'char 3': '867 471 7 11',
#    'char 4': '878 471 8 12',
#    'char 5': '887 472 4 11',
#    'char 6': '893 472 7 11',
#    'char 7': '900 472 8 11'},
#   'track0104[03]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '762 376 211 188',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '842 461 57 19',
#    'char 1': '845 468 7 11',
#    'char 2': '852 468 7 11',
#    'char 3': '859 468 7 11',
#    'char 4': '869 468 7 11',
#    'char 5': '878 468 3 11',
#    'char 6': '883 468 7 11',
#    'char 7': '889 468 7 11'},
#   'track0104[09]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '758 378 219 194',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '842 465 58 21',
#    'char 1': '844 473 8 10',
#    'char 2': '851 472 8 11',
#    'char 3': '858 473 8 11',
#    'char 4': '869 473 7 10',
#    'char 5': '877 473 4 10',
#    'char 6': '883 473 7 11',
#    'char 7': '890 473 7 11'},
#   'track0104[26]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '758 376 245 219',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '851 473 66 25',
#    'char 1': '854 482 8 12',
#    'char 2': '862 482 8 12',
#    'char 3': '870 482 8 12',
#    'char 4': '882 482 8 13',
#    'char 5': '892 483 4 11',
#    'char 6': '898 483 7 12',
#    'char 7': '906 483 7 12'},
#   'track0104[02]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '763 376 209 188',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '844 460 56 19',
#    'char 1': '846 467 7 11',
#    'char 2': '853 466 7 11',
#    'char 3': '860 467 7 11',
#    'char 4': '870 467 7 11',
#    'char 5': '878 467 4 11',
#    'char 6': '883 467 7 11',
#    'char 7': '890 467 7 11'},
#   'track0104[17]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '759 372 231 204',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '846 462 62 23',
#    'char 1': '849 470 7 12',
#    'char 2': '857 470 7 11',
#    'char 3': '864 470 7 12',
#    'char 4': '875 471 8 11',
#    'char 5': '884 471 4 12',
#    'char 6': '889 471 8 12',
#    'char 7': '897 471 8 12'},
#   'track0104[12]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '758 374 222 199',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '842 463 60 21',
#    'char 1': '845 470 8 11',
#    'char 2': '852 470 8 11',
#    'char 3': '860 470 7 11',
#    'char 4': '871 470 7 12',
#    'char 5': '879 471 4 11',
#    'char 6': '884 471 8 11',
#    'char 7': '892 471 7 11'},
#   'track0104[29]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '755 373 252 222',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '850 472 68 25',
#    'char 1': '854 480 7 13',
#    'char 2': '862 480 8 13',
#    'char 3': '870 481 8 12',
#    'char 4': '882 481 8 13',
#    'char 5': '892 481 4 14',
#    'char 6': '898 482 8 12',
#    'char 7': '906 482 8 13'},
#   'track0104[06]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '759 379 215 191',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '841 465 58 20',
#    'char 1': '844 473 7 9',
#    'char 2': '851 472 7 10',
#    'char 3': '858 473 7 10',
#    'char 4': '868 473 7 10',
#    'char 5': '877 473 3 10',
#    'char 6': '882 473 7 10',
#    'char 7': '889 473 6 10'},
#   'track0104[27]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '758 376 247 219',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '850 474 68 24',
#    'char 1': '854 482 7 12',
#    'char 2': '862 482 8 12',
#    'char 3': '870 482 7 12',
#    'char 4': '882 483 8 12',
#    'char 5': '892 483 3 12',
#    'char 6': '898 484 8 11',
#    'char 7': '906 484 8 12'},
#   'track0104[25]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '758 377 243 223',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '850 473 66 24',
#    'char 1': '854 481 7 13',
#    'char 2': '862 481 8 13',
#    'char 3': '870 482 7 12',
#    'char 4': '882 482 8 12',
#    'char 5': '891 482 4 13',
#    'char 6': '897 483 8 12',
#    'char 7': '905 483 8 12'},
#   'track0104[10]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '759 376 219 196',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '843 464 58 21',
#    'char 1': '845 471 7 11',
#    'char 2': '852 470 7 12',
#    'char 3': '859 471 8 11',
#    'char 4': '870 471 7 11',
#    'char 5': '879 472 3 10',
#    'char 6': '884 472 7 11',
#    'char 7': '891 472 7 11'},
#   'track0104[28]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '756 374 248 222',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '850 473 67 25',
#    'char 1': '853 482 8 12',
#    'char 2': '861 481 8 13',
#    'char 3': '869 482 8 12',
#    'char 4': '882 483 8 12',
#    'char 5': '892 483 4 12',
#    'char 6': '898 483 7 12',
#    'char 7': '906 483 8 12'},
#   'track0104[08]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '758 378 218 194',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '842 466 58 20',
#    'char 1': '844 473 8 11',
#    'char 2': '851 472 7 11',
#    'char 3': '858 473 8 11',
#    'char 4': '869 473 7 11',
#    'char 5': '877 473 4 11',
#    'char 6': '883 473 6 11',
#    'char 7': '889 474 8 10'},
#   'track0104[15]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '759 372 227 201',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '845 461 61 23',
#    'char 1': '848 469 7 12',
#    'char 2': '855 469 8 12',
#    'char 3': '862 469 7 12',
#    'char 4': '873 470 8 11',
#    'char 5': '882 470 4 11',
#    'char 6': '888 470 7 11',
#    'char 7': '895 470 8 12'},
#   'track0104[11]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '759 375 219 197',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '842 463 59 21',
#    'char 1': '844 470 8 12',
#    'char 2': '852 470 7 11',
#    'char 3': '859 471 8 11',
#    'char 4': '870 471 8 11',
#    'char 5': '878 470 5 12',
#    'char 6': '884 471 7 11',
#    'char 7': '891 471 7 11'},
#   'track0104[20]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '760 373 235 208',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '850 465 64 23',
#    'char 1': '853 473 8 12',
#    'char 2': '861 473 8 12',
#    'char 3': '868 473 8 12',
#    'char 4': '880 474 8 11',
#    'char 5': '889 474 4 12',
#    'char 6': '894 474 8 12',
#    'char 7': '902 475 8 11'},
#   'track0104[05]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '760 378 214 191',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '842 464 57 20',
#    'char 1': '844 470 7 11',
#    'char 2': '851 470 7 11',
#    'char 3': '858 472 7 10',
#    'char 4': '868 471 7 11',
#    'char 5': '877 472 3 10',
#    'char 6': '882 471 7 10',
#    'char 7': '889 471 7 11'},
#   'track0104[30]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '753 371 253 224',
#    'type': 'car',
#    'make': 'Renault',
#    'model': 'Clio',
#    'year': '2000',
#    'plate': 'APL-0100',
#    'position_plate': '848 471 69 26',
#    'char 1': '852 479 8 13',
#    'char 2': '860 480 8 13',
#    'char 3': '868 480 8 13',
#    'char 4': '880 481 9 12',
#    'char 5': '891 481 3 13',
#    'char 6': '897 481 7 13',
#    'char 7': '905 482 7 12'},
#   'track0096[13]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '1255 313 317 304',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2013',
#    'plate': 'AWX-9307',
#    'position_plate': '1386 528 81 35',
#    'char 1': '1391 538 10 15',
#    'char 2': '1401 538 10 16',
#    'char 3': '1410 540 12 15',
#    'char 4': '1424 542 10 14',
#    'char 5': '1434 543 9 14',
#    'char 6': '1443 544 10 14',
#    'char 7': '1453 544 9 16'},
#   'track0096[18]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '1320 325 323 302',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2013',
#    'plate': 'AWX-9307',
#    'position_plate': '1465 537 78 35',
#    'char 1': '1469 547 10 15',
#    'char 2': '1479 548 10 15',
#    'char 3': '1488 549 10 15',
#    'char 4': '1501 551 10 15',
#    'char 5': '1511 552 9 15',
#    'char 6': '1520 554 9 13',
#    'char 7': '1529 554 9 15'},
#   'track0096[12]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '1243 310 317 302',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2013',
#    'plate': 'AWX-9307',
#    'position_plate': '1371 527 81 34',
#    'char 1': '1376 537 10 14',
#    'char 2': '1386 537 11 15',
#    'char 3': '1395 538 11 16',
#    'char 4': '1409 540 11 15',
#    'char 5': '1419 541 10 15',
#    'char 6': '1429 542 9 14',
#    'char 7': '1438 542 9 16'},
#   'track0096[25]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '1420 343 328 296',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2013',
#    'plate': 'AWX-9307',
#    'position_plate': '1581 549 74 36',
#    'char 1': '1585 559 9 14',
#    'char 2': '1594 560 10 14',
#    'char 3': '1603 561 10 14',
#    'char 4': '1615 563 10 14',
#    'char 5': '1624 564 9 14',
#    'char 6': '1633 566 8 14',
#    'char 7': '1641 566 9 16'},
#   'track0096[11]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '1231 308 314 308',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2013',
#    'plate': 'AWX-9307',
#    'position_plate': '1357 526 81 34',
#    'char 1': '1361 536 10 15',
#    'char 2': '1371 536 11 15',
#    'char 3': '1381 537 10 16',
#    'char 4': '1395 539 10 15',
#    'char 5': '1405 540 9 15',
#    'char 6': '1414 541 10 14',
#    'char 7': '1423 541 10 15'},
#   'track0096[24]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '1407 340 327 296',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2013',
#    'plate': 'AWX-9307',
#    'position_plate': '1564 547 74 35',
#    'char 1': '1568 556 9 14',
#    'char 2': '1578 557 9 14',
#    'char 3': '1586 558 10 15',
#    'char 4': '1598 561 10 14',
#    'char 5': '1607 562 10 14',
#    'char 6': '1616 563 9 14',
#    'char 7': '1625 564 8 15'},
#   'track0096[19]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '1336 327 322 300',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2013',
#    'plate': 'AWX-9307',
#    'position_plate': '1481 539 78 35',
#    'char 1': '1486 550 9 14',
#    'char 2': '1495 550 10 15',
#    'char 3': '1504 551 11 15',
#    'char 4': '1517 554 10 14',
#    'char 5': '1526 555 10 14',
#    'char 6': '1535 556 10 14',
#    'char 7': '1544 557 10 14'},
#   'track0096[23]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '1391 338 327 298',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2013',
#    'plate': 'AWX-9307',
#    'position_plate': '1547 546 75 35',
#    'char 1': '1551 555 9 15',
#    'char 2': '1561 556 9 14',
#    'char 3': '1570 557 9 15',
#    'char 4': '1582 560 9 14',
#    'char 5': '1591 561 9 14',
#    'char 6': '1599 562 9 14',
#    'char 7': '1608 563 9 15'},
#   'track0096[26]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '1435 343 329 292',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2013',
#    'plate': 'AWX-9307',
#    'position_plate': '1598 549 73 36',
#    'char 1': '1602 559 9 14',
#    'char 2': '1611 560 10 14',
#    'char 3': '1619 561 10 15',
#    'char 4': '1632 564 9 13',
#    'char 5': '1640 565 10 14',
#    'char 6': '1649 567 9 14',
#    'char 7': '1658 568 8 14'},
#   'track0096[15]': {'camera': 'GoPro Hero4 Silver',
#    'position_vehicle': '1282 316 319 303',
#    'type': 'car',
#    'make': 'JAC',
#    'model': 'J2',
#    'year': '2013',
#    'plate': 'AWX-9307',
#    'position_plate': '1417 531 80 35',
#    'char 1': '1421 541 10 15',
#    'char 2': '1432 542 10 15',
#    'char 3': '1441 543 11 15',
#    'char 4': '1454 545 11 14',
#    'char 5': '1464 546 10 15',
#    'char 6': '1473 547 10 15',
#    'char 7': '1483 548 9 15'},
#   ...}}

# %% [markdown]
# ## Script

# %%
arq_imagens = [png for png in os.listdir(filepath) if png.endswith(".png")]
ext_imagens = [nn.replace(".png", "") for nn in arq_imagens]

for aimg, exti in zip(arq_imagens, ext_imagens):
  img = cv2.imread(filepath + aimg)
  gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
  rimg = Image(gray, exti, metadata['training'][exti])
  rimg.crop_plate(save=True)
