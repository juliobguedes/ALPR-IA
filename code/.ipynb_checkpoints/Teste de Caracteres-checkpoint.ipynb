# %%
import cv2

import matplotlib as mpl
from matplotlib import pyplot as plt
# %matplotlib inline

import numpy as np
import pandas as pd

import os, json, itertools

# %%
path = u'../data/placas/'
metadata_db = json.load(open('../data/metadata_db.json', 'r'))

# %%
def plot(imagem):
    plt.figure(figsize=(30,12))
    plt.imshow(imagem, cmap="gray")
    plt.tick_params(bottom=False, labelbottom=False, left=False, labelleft=False)

# %%
np.random.seed(12321)

# %%
arq = os.listdir(path)
arq.sort()

num = 10
arq = arq[:num]
# Out:
# ['track0001[01].png',
#  'track0001[02].png',
#  'track0001[03].png',
#  'track0001[04].png',
#  'track0001[05].png',
#  'track0001[06].png',
#  'track0001[07].png',
#  'track0001[08].png',
#  'track0001[09].png',
#  'track0001[10].png']

# %%
ext = [a.replace('.png','') for a in arq]

grayscale = []

for a in arq:
    ppath = path + a
    imagem = cv2.imread(path+a, 0)
    grayscale.append(imagem)

# %%
imagem = grayscale[0]
plot(imagem)

# %% [markdown]
# ### Blurring

# %%
plt.figure(figsize=(20, 10))
plt.subplot(2,3,1)
plt.title("Original")
plt.imshow(imagem, cmap="gray")

nbins = 64
h, bin_edges = np.histogram(imagem.ravel(), nbins, (0, 255))
w = 256./nbins

bin_centers = bin_edges[1:] - (w/2)
plt.subplot(2,3,4)
plt.title("Histograma Original")
plt.bar(bin_centers, h, width=w)

###################################################################

plt.subplot(2,3,2)
teste_media = cv2.blur(imagem, (3,3))
plt.title("Filtro de média")
plt.imshow(teste_media, cmap="gray")

nbins = 64
h, bin_edges = np.histogram(teste_media.ravel(), nbins, (0, 255))
w = 256 / nbins

bin_centers = bin_edges[1:] - (w/2)
plt.subplot(2,3,5)
plt.title("Histograma de média")
plt.bar(bin_centers, h, width=w)

###################################################################

plt.subplot(2,3,3)
teste_eql = cv2.equalizeHist(imagem, (3,3))
plt.title("Imagem Equalizada")
plt.imshow(teste_eql, cmap="gray")

nbins = 64
h, bin_edges = np.histogram(teste_eql.ravel(), nbins, (0, 255))
w = 256 / nbins

bin_centers = bin_edges[1:] - (w/2)
plt.subplot(2,3,6)
plt.title("Histograma Equalizado")
plt.bar(bin_centers, h, width=w)
# Out:
# <BarContainer object of 64 artists>

# %% [markdown]
# ### Thresholding

# %%
sobelx = cv2.Sobel(teste_eql, cv2.CV_64F, 1, 0, ksize=3)
plot(sobelx)

# %%
sobelxn = cv2.normalize(sobelx, None, alpha = 0, beta = 255,
                          norm_type = cv2.NORM_MINMAX, dtype = cv2.CV_8U)
plot(sobelxn)

# %%
_, xthrg = cv2.threshold(sobelxn, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
plot(xthrg)

# %%
canny = cv2.Canny(teste_eql, 300, 100)
plot(canny)

# %%
xthr = cv2.adaptiveThreshold(sobelxn, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 3, 0)
plot(xthr)

# %%
_, th = cv2.threshold(teste_eql, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
plot(th)

# %%
opening = cv2.morphologyEx(th, cv2.MORPH_CLOSE, (19,19))
plot(opening)

# %% [markdown]
# ### Contornos

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5,13))
morphDx = cv2.dilate(th, kernel, 1)

morphDx = ~ morphDx

_, contours1, hierarch = cv2.findContours(morphDx, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

img_cont1 = cv2.cvtColor(th, cv2.COLOR_GRAY2BGR)
cv2.drawContours(img_cont1, contours1, -1, (0, 255, 0), 3)
plt.figure(figsize=(30,12))
plt.imshow(img_cont1, cmap="gray")

# %%
color = cv2.cvtColor(th, cv2.COLOR_GRAY2BGR)

for cnt in contours1:
  epsilon = 0.05 * cv2.arcLength(cnt, True)
  approx = cv2.approxPolyDP(cnt,epsilon,True)
  
  if (len(approx) == 4):
    x, y, w, h = cv2.boundingRect(cnt)
    cv2.rectangle(color, (x,y), (x+w, y+h), (255, 0, 0), 2)
    ar = 1.0 * h / 2

    if (ar >= 0.3 and ar <= 20 and h * w >= 2000 and h * w <= 23000):
      print (ar, h, w, h*w)
      cv2.rectangle(color, (x,y),(x+w, y+h), (0, 255, 0), 8)
      
plt.figure(figsize=(30,12))
plt.imshow(color, cmap="gray")
